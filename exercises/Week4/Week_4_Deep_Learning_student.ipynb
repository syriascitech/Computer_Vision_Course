# %% [markdown]
# <a href="https://colab.research.google.com/github/syriascitech/Computer_Vision_Course/blob/main/exercises/Week4/Week_4_Deep_Learning_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir="rtl">
#
# # 🧪 Week 4 — Deep Learning Basics Practical Lab
# ### مختبر الأسبوع 4 العملي — أساسيات التعلم العميق
#
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>1. Lab Overview</h2>
# <p style="direction: rtl; text-align: right;">هذا المختبر عبارة عن مجموعة تمارين عملية تفاعلية لمستوى <strong>Practical</strong>، مُشتقة مباشرة من محتوى دفتر الأسبوع 4 (<code>Week_4_Deep_Learning_Basics.ipynb</code>): العصبون (Neuron)، الأوزان (Weights)، الانحياز (Bias)، الجمع المرجح (Weighted Sum)، دوال التنشيط (Activation Functions)، الـ Perceptron، بوابات AND/OR، مشكلة XOR وحلها بشبكة من طبقتين، قاعدة تعلم البيرسيبترون (Perceptron Learning Rule)، والعصبون الحديث (Modern Neuron) مع ReLU.</p>
# <p style="direction: rtl; text-align: right;">الهدف هو <strong>الممارسة العملية (Hands-on Practice)</strong> عبر كتابة كود Python/NumPy فعلي، وليس الإجابة على أسئلة نظرية فقط.</p>
# </div>
# ---

# %% [markdown]
# <div dir="rtl">
# <h2>2. Learning Objectives</h2>
#
# <p style="direction: rtl; text-align: right;">بنهاية هذا المختبر، ستكون قادراً على:</p>
#
# <ul style="direction: rtl; text-align: right;">
# <li>حساب الجمع المرجح (Weighted Sum) يدوياً باستخدام NumPy.</li>
# <li>فهم أثر تغيير الأوزان (Weights) والانحياز (Bias) على قرار العصبون.</li>
# <li>تطبيق دالتي تنشيط: <strong>Step Function</strong> و <strong>ReLU</strong>.</li>
# <li>بناء عصبون Perceptron كامل (Weighted Sum + Activation).</li>
# <li>بناء بوابات منطقية AND و OR باستخدام عصبون واحد.</li>
# <li>رسم خط الفصل (Decision Boundary) لعصبون واحد.</li>
# <li>إثبات عملياً أن العصبون الواحد لا يستطيع حل مشكلة XOR.</li>
# <li>بناء شبكة من طبقتين (Hidden Layer + Output Layer) لحل XOR.</li>
# <li>تطبيق قاعدة تعلم البيرسيبترون (Perceptron Learning Rule) لتحديث الأوزان تلقائياً.</li>
# <li>بناء طبقة من عدة عصبونات باستخدام ضرب المصفوفات (Matrix Multiplication) وتنفيذ Forward Pass عبر أكثر من طبقة مع ReLU.</li>
# </ul>
#
# </div>
#
# ---

# %% [markdown]
# <div dir="rtl">
# <h2>3. Environment Setup</h2>
#
# <p style="direction: rtl; text-align: right;">سنستخدم فقط المكتبات المستخدمة في دفتر الأسبوع 4: <code>numpy</code> و <code>matplotlib</code>. نفّذ الخلية التالية للتأكد من أن بيئتك جاهزة.</p>
#
# </div>

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

print("NumPy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("✅ Environment ready.")
# Out:
# NumPy: 2.5.2
# matplotlib: 3.11.1
# ✅ Environment ready.

# %% [markdown]
# <div dir="rtl">
# <blockquote style="direction: rtl; text-align: right; border-right: 4px solid #ccc; padding-right: 10px; margin-right: 0;">
# <p style="direction: rtl; text-align: right;">إذا ظهر رقم إصدار <code>numpy</code> و <code>matplotlib</code> بدون أي خطأ، فبيئتك جاهزة للانتقال إلى التمارين. 👍</p>
# </blockquote>
# </div>
#
# ---

# %% [markdown]
# <div dir="rtl">
# <h2>4. How to Use This Notebook</h2>
#
# <p style="direction: rtl; text-align: right;">كل تمرين في هذا المختبر يتبع نفس الهيكل بالضبط:</p>
#
# </div>
#
# <pre style="direction: ltr; text-align: left; background-color: #f5f5f5; padding: 10px; border-radius: 5px; unicode-bidi: bidi-override;">
# Exercise
#    ↓
# Topic / Difficulty / Objective
#    ↓
# Scenario
#    ↓
# Task / Requirements / Expected Result
#    ↓
# Hints
#    ↓
# 🧑‍💻 Your Solution
#    ↓
# ✅ Self-Check
#    ↓
# 💡 Show Solution
# </pre>
#
# <div dir="rtl">
# <p style="direction: rtl; text-align: right;"><strong>قاعدة ذهبية:</strong> حاول حل كل تمرين بنفسك وتشغيل خلية <strong>Self-Check</strong> بنجاح قبل فتح <strong>Show Solution</strong>. الحل موجود دائماً لكنه مطوي عن قصد.</p>
# </div>
#
# ---

# %% [markdown]
# <div dir="rtl">
# <h2>5. Exercise 1 — Manual Neuron Calculation</h2>
# <h3>تمرين 1 — الحساب اليدوي لعصبون واحد</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> العصبون (Neuron)، المدخلات (Inputs)، الأوزان (Weights)، الانحياز (Bias)، الجمع المرجح (Weighted Sum)</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من حساب الجمع المرجح لعصبون واحد يدوياً باستخدام NumPy، وفهم أن هذه العملية الحسابية البسيطة هي أساس كل شبكة عصبية.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">قبل بناء أي شبكة عصبية، يجب أن تفهم أن العصبون الواحد ما هو إلا عملية ضرب وجمع بسيطة. تخيل أن لديك عصبوناً يستقبل قيمتي بكسل من صورة صغيرة، ويريد أن يحسب "إشارته" الأولية قبل أي دالة تنشيط.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>أنشئ مصفوفة <code>inputs</code> تحتوي القيمتين <code>[0.6, 0.9]</code>.</li>
# <li>أنشئ مصفوفة <code>weights</code> تحتوي القيمتين <code>[0.3, -0.1]</code>.</li>
# <li>عرّف متغيراً <code>bias</code> يساوي <code>0.05</code>.</li>
# <li>احسب الجمع المرجح وخزّنه في متغير اسمه <code>weighted_sum</code> باستخدام <code>np.dot</code>.</li>
# <li>اطبع القيمة النهائية بدقة رقمين عشريين.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>استخدم <code>numpy</code> فقط.</li>
# <li>يجب استخدام <code>np.dot</code> لحساب حاصل الضرب.</li>
# <li>أسماء المتغيرات يجب أن تكون بالضبط: <code>inputs</code>, <code>weights</code>, <code>bias</code>, <code>weighted_sum</code>.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>طباعة قيمة <code>weighted_sum</code> تساوي تقريباً <code>0.14</code>.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع معادلة الجمع المرجح في الدرس: $Z = w_1x_1 + w_2x_2 + b$. هذه العملية هي حاصل ضرب نقطي (Dot Product) بين المدخلات والأوزان، بالإضافة إلى الانحياز.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# في NumPy، حاصل الضرب النقطي بين مصفوفتين يتم عبر `np.dot(a, b)`. تذكر أن الانحياز يُضاف بعد عملية الضرب النقطي، وليس قبلها.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# الكود العام هو: `weighted_sum = np.dot(inputs, weights) + bias`. تأكد أن `inputs` و `weights` كلاهما مصفوفات NumPy بنفس الطول.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Create the `inputs` array with values [0.6, 0.9]
# 2. Create the `weights` array with values [0.3, -0.1]
# 3. Define `bias` as 0.05
# 4. Compute `weighted_sum` using np.dot
# 5. Print weighted_sum rounded to 2 decimals

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'inputs' in dir(), "Variable 'inputs' not found."
assert 'weights' in dir(), "Variable 'weights' not found."
assert 'bias' in dir(), "Variable 'bias' not found."
assert 'weighted_sum' in dir(), "Variable 'weighted_sum' not found."

assert isinstance(inputs, np.ndarray), "`inputs` should be a NumPy array."
assert isinstance(weights, np.ndarray), "`weights` should be a NumPy array."
assert inputs.shape == (2,), f"Expected `inputs` shape (2,), got {inputs.shape}"
assert weights.shape == (2,), f"Expected `weights` shape (2,), got {weights.shape}"

expected = np.dot(np.array([0.6, 0.9]), np.array([0.3, -0.1])) + 0.05
assert abs(weighted_sum - expected) < 1e-6, f"Expected weighted_sum ≈ {expected:.4f}, got {weighted_sum}"

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>6. Exercise 2 — Weights &amp; Bias Sensitivity</h2>
# <h3>تمرين 2 — حساسية الأوزان والانحياز</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> تأثير الأوزان (Weights Sensitivity) على قرار العصبون</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تفهم عملياً أن تغيير الأوزان فقط (دون تغيير المدخلات) يغيّر تماماً "انتباه" العصبون واستجابته — وهذا هو جوهر عملية التعلّم في الشبكات العصبية.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">لديك بكسلان من صورة: بكسل ساطع جداً وبكسل باهت جداً. تريد أن تبني عصبونين بأوزان مختلفة: الأول "يهتم" فقط بالبكسل الأول، والثاني "يهتم" فقط بالبكسل الثاني، لتلاحظ كيف يغيّر الوزن استجابة العصبون لنفس المدخل تماماً.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف دالة <code>weighted_response(x, w)</code> تحسب وتُعيد حاصل الضرب النقطي <code>np.dot(x, w)</code> (بدون انحياز وبدون تنشيط).</li>
# <li>أنشئ مصفوفة مدخلات <code>image_pixels = np.array([0.9, 0.1])</code>.</li>
# <li>أنشئ وزنين مختلفين: <code>w_focus_first = np.array([1.0, 0.0])</code> و <code>w_focus_second = np.array([0.0, 1.0])</code>.</li>
# <li>احسب <code>response_first = weighted_response(image_pixels, w_focus_first)</code> و <code>response_second = weighted_response(image_pixels, w_focus_second)</code>.</li>
# <li>اطبع كلتا القيمتين ووضّح أيهما أعلى.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>يجب استخدام دالة باسم <code>weighted_response</code> بالضبط.</li>
# <li>لا تستخدم أي دالة تنشيط في هذا التمرين — فقط الجمع المرجح.</li>
# <li>استخدم <code>numpy</code> فقط.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>response_first</code> يجب أن يساوي <code>0.9</code> (لأن الوزن الأول يعطي أهمية كاملة للبكسل الساطع)، بينما <code>response_second</code> يجب أن يساوي <code>0.1</code>.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# الوزن الذي يساوي `1.0` "يمرر" المدخل كاملاً، بينما الوزن الذي يساوي `0.0` "يتجاهله" تماماً. فكّر في `np.dot` كأداة توزن أهمية كل مدخل.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# الدالة `weighted_response` يجب أن تكون سطراً واحداً تقريباً: `return np.dot(x, w)`.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# نفّذ: `response_first = weighted_response(image_pixels, w_focus_first)` ثم كرر نفس الخطوة مع `w_focus_second`، وقارن بين القيمتين بالطباعة.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define weighted_response(x, w) using np.dot (no bias, no activation)
# 2. Create image_pixels = [0.9, 0.1]
# 3. Create w_focus_first = [1.0, 0.0] and w_focus_second = [0.0, 1.0]
# 4. Compute response_first and response_second
# 5. Print both values

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'weighted_response' in dir(), "Function 'weighted_response' not found."
assert callable(weighted_response), "'weighted_response' should be a function."
assert 'response_first' in dir(), "Variable 'response_first' not found."
assert 'response_second' in dir(), "Variable 'response_second' not found."

assert abs(response_first - 0.9) < 1e-6, f"Expected response_first ≈ 0.9, got {response_first}"
assert abs(response_second - 0.1) < 1e-6, f"Expected response_second ≈ 0.1, got {response_second}"
assert response_first != response_second, "Different weights should produce different responses for these inputs."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>7. Exercise 3 — Activation Functions: Step vs ReLU</h2>
# <h3>تمرين 3 — دوال التنشيط: Step مقابل ReLU</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> دوال التنشيط (Activation Functions) — Step Function و ReLU</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من تطبيق دالتي تنشيط مختلفتين (Step Function القديمة و ReLU الحديثة) على نفس مجموعة القيم، وملاحظة الفرق الجوهري بين مخرجاتهما.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">بعد حساب الجمع المرجح، يحتاج العصبون إلى دالة تنشيط لتحويل الإشارة الخام إلى قرار أو استجابة. سنقارن هنا بين دالة العتبة الصلبة (Step) المستخدمة في الـ Perceptron التقليدي، ودالة ReLU المستخدمة في العصبون الحديث.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف دالة <code>step_function(x)</code> تُعيد <code>1</code> إذا كان <code>x &gt;= 0</code> وإلا تُعيد <code>0</code> (لقيمة عددية واحدة).</li>
# <li>عرّف دالة <code>relu(x)</code> تُعيد <code>np.maximum(0, x)</code> (تعمل على مصفوفات كاملة).</li>
# <li>أنشئ مصفوفة <code>signals = np.array([-1.5, 0.4, -0.2, 2.1, 0.0])</code>.</li>
# <li>طبّق <code>relu</code> على <code>signals</code> وخزّن الناتج في <code>relu_outputs</code>.</li>
# <li>طبّق <code>step_function</code> على كل عنصر في <code>signals</code> بشكل منفصل (باستخدام حلقة أو list comprehension) وخزّن النتائج في قائمة اسمها <code>step_outputs</code>.</li>
# <li>اطبع القيمتين <code>relu_outputs</code> و <code>step_outputs</code>.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>relu</code> يجب أن تستخدم <code>np.maximum</code>.</li>
# <li><code>step_function</code> يجب أن تعمل على قيمة عددية واحدة فقط (Scalar).</li>
# <li><code>step_outputs</code> يجب أن تكون <code>list</code> من نوع Python، بينما <code>relu_outputs</code> تكون <code>np.ndarray</code>.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>relu_outputs</code> تساوي تقريباً <code>[0., 0.4, 0., 2.1, 0.]</code>، بينما <code>step_outputs</code> تساوي <code>[0, 1, 0, 1, 1]</code>.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع كود ReLU في الدرس: `def relu(x): return np.maximum(0, x)`. لدالة الخطوة، تذكّر معادلة الـ Perceptron الأصلية: `1 if Z >= 0 else 0`.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# لتطبيق `step_function` على كل عنصر في مصفوفة، استخدم list comprehension: `[step_function(s) for s in signals]`.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# لاحظ الفرق الجوهري: `relu(0.4)` تُعيد `0.4` نفسها (تحافظ على القيمة)، بينما `step_function(0.4)` تُعيد `1` فقط (قرار حاد). هذا هو الفرق بين العصبون الحديث والـ Perceptron التقليدي.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define step_function(x) -> 1 if x >= 0 else 0
# 2. Define relu(x) -> np.maximum(0, x)
# 3. Create signals = [-1.5, 0.4, -0.2, 2.1, 0.0]
# 4. Compute relu_outputs = relu(signals)
# 5. Compute step_outputs as a list applying step_function to each element
# 6. Print both results

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'step_function' in dir(), "Function 'step_function' not found."
assert 'relu' in dir(), "Function 'relu' not found."
assert 'signals' in dir(), "Variable 'signals' not found."
assert 'relu_outputs' in dir(), "Variable 'relu_outputs' not found."
assert 'step_outputs' in dir(), "Variable 'step_outputs' not found."

assert step_function(-0.1) == 0, "step_function(-0.1) should be 0."
assert step_function(0) == 1, "step_function(0) should be 1 (Z >= 0 rule)."
assert list(relu(np.array([-2, 3]))) == [0, 3], "relu should zero-out negatives and keep positives."

expected_relu = np.maximum(0, np.array([-1.5, 0.4, -0.2, 2.1, 0.0]))
assert np.allclose(relu_outputs, expected_relu), f"Expected relu_outputs ≈ {expected_relu}, got {relu_outputs}"

expected_step = [0, 1, 0, 1, 1]
assert list(step_outputs) == expected_step, f"Expected step_outputs {expected_step}, got {list(step_outputs)}"

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>8. Exercise 4 — Building a Single Perceptron</h2>
# <h3>تمرين 4 — بناء عصبون Perceptron كامل</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> الـ Perceptron — دمج الجمع المرجح مع دالة التنشيط</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من بناء دالة Perceptron كاملة تجمع بين الجمع المرجح ودالة العتبة (Step Function) في خطوة واحدة، وتُعيد قراراً ثنائياً <code>0</code> أو <code>1</code>.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">حتى الآن تعاملت مع الجمع المرجح والتنشيط كخطوتين منفصلتين. في الواقع، العصبون الحقيقي (Perceptron) يقوم بالخطوتين معاً كوحدة واحدة. سنبني الآن دالة <code>perceptron</code> عامة قابلة لإعادة الاستخدام مع أي أوزان وانحياز.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف دالة <code>perceptron(x1, x2, w1, w2, bias)</code> تحسب الجمع المرجح <code>(x1*w1) + (x2*w2) + bias</code> ثم تمرره عبر دالة عتبة (Step Function) داخلية أو مُعرّفة مسبقاً، وتُعيد <code>1</code> أو <code>0</code>.</li>
# <li>اختبر الدالة على النقطة <code>(x1=1.0, x2=1.0)</code> باستخدام الأوزان <code>w1=0.6, w2=0.6</code> والانحياز <code>bias=-0.9</code>، وخزّن الناتج في <code>test_output_a</code>.</li>
# <li>اختبر الدالة على النقطة <code>(x1=0.1, x2=0.1)</code> بنفس الأوزان والانحياز، وخزّن الناتج في <code>test_output_b</code>.</li>
# <li>اطبع كلا الناتجين مع توضيح أي نقطة "نشّطت" العصبون.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>الدالة يجب أن تُسمّى <code>perceptron</code> بالضبط وتقبل الوسائط الخمسة بنفس الترتيب.</li>
# <li>يجب أن تُعيد الدالة عدداً صحيحاً (<code>0</code> أو <code>1</code>) فقط، وليس قيمة عشرية.</li>
# <li>يمكنك إعادة استخدام <code>step_function</code> من التمرين السابق إن أردت.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>test_output_a</code> يجب أن يساوي <code>1</code> (لأن الجمع المرجح موجب)، بينما <code>test_output_b</code> يجب أن يساوي <code>0</code> (لأن الجمع المرجح سالب بوضوح).</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع بنية دالة `single_neuron` في الدرس: تحسب `linear_sum = (x1*w1)+(x2*w2)+bias` ثم تمررها لدالة العتبة.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# احسب يدوياً للتأكد: عند `(1.0, 1.0)` الجمع المرجح هو `1.0*0.6 + 1.0*0.6 - 0.9 = 0.6 + 0.6 - 0.9 = 0.3`، وهذا `>= 0` فيُعطي `1`.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# الكود العام: `linear_sum = (x1*w1) + (x2*w2) + bias` ثم `return 1 if linear_sum >= 0 else 0`.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define perceptron(x1, x2, w1, w2, bias) combining weighted sum + step activation
# 2. Compute test_output_a for (1.0, 1.0) with w1=0.6, w2=0.6, bias=-0.9
# 3. Compute test_output_b for (0.1, 0.1) with the same weights/bias
# 4. Print both outputs

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'perceptron' in dir(), "Function 'perceptron' not found."
assert callable(perceptron), "'perceptron' should be a function."
assert 'test_output_a' in dir(), "Variable 'test_output_a' not found."
assert 'test_output_b' in dir(), "Variable 'test_output_b' not found."

assert perceptron(0, 0, 1, 1, -0.5) in [0, 1], "perceptron should return only 0 or 1."
assert test_output_a == 1, f"Expected test_output_a == 1, got {test_output_a}"
assert test_output_b == 0, f"Expected test_output_b == 0, got {test_output_b}"
assert perceptron(1.0, 1.0, 0.6, 0.6, -0.9) == test_output_a, "perceptron(...) should reproduce test_output_a exactly."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>9. Exercise 5 — Building AND / OR Logic Gates</h2>
# <h3>تمرين 5 — بناء بوابتي AND و OR باستخدام عصبون واحد</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> بوابات منطقية خطية (AND / OR) باستخدام Perceptron واحد</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من ضبط أوزان وانحياز عصبون واحد يدوياً ليحاكي بوابتي AND و OR المنطقيتين، وفهم لماذا يكفي عصبون واحد لحل بيانات قابلة للفصل الخطي.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">بوابتا AND و OR هما مثالان كلاسيكيان على بيانات "قابلة للفصل الخطي" (Linearly Separable) — يمكن لخط مستقيم واحد أن يفصل بين المخرجات الصحيحة والخاطئة. سنستخدم دالة <code>perceptron</code> التي بنيتها سابقاً لاختبار ذلك على المدخلات الأربعة الممكنة.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>أنشئ قائمة <code>gate_inputs = [[0, 0], [0, 1], [1, 0], [1, 1]]</code>.</li>
# <li>باستخدام دالة <code>perceptron</code> من التمرين السابق مع الأوزان <code>w1=1, w2=1, bias=-1.5</code>، احسب مخرجات بوابة AND لكل مدخل، وخزّنها في قائمة <code>and_results</code>.</li>
# <li>باستخدام نفس الدالة مع الأوزان <code>w1=1, w2=1, bias=-0.5</code>، احسب مخرجات بوابة OR لكل مدخل، وخزّنها في قائمة <code>or_results</code>.</li>
# <li>اطبع كلتا القائمتين بشكل واضح إلى جانب المدخلات المقابلة لهما.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>استخدم دالة <code>perceptron</code> المبنية مسبقاً — لا تكتب منطق تنشيط جديد.</li>
# <li><code>and_results</code> و <code>or_results</code> يجب أن تكونا من نوع <code>list</code> بطول 4.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>and_results</code> يجب أن تساوي <code>[0, 0, 0, 1]</code> (فقط <code>[1,1]</code> تُفعّل AND)، و <code>or_results</code> يجب أن تساوي <code>[0, 1, 1, 1]</code> (أي مدخل واحد على الأقل يساوي 1 يكفي).</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع جدول الحقيقة لبوابتي AND و OR. لبوابة AND، يجب أن يكون كلا المدخلين `1` معاً لتخطي العتبة. لبوابة OR، مدخل واحد فقط يكفي.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# الانحياز `-1.5` مع أوزان `1, 1` يعني أن الجمع المرجح يجب أن يصل `1.5` على الأقل للتفعيل — وهذا لا يحدث إلا عند `[1,1]` (المجموع = 2). أما `-0.5` فيكفي معه مجموع `0.5` فقط، وهذا يتحقق مع أي مدخل واحد يساوي `1`.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# استخدم حلقة تكرارية: `and_results = [perceptron(x[0], x[1], 1, 1, -1.5) for x in gate_inputs]`، وكرر بنفس الطريقة لـ OR بانحياز مختلف.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Create gate_inputs = [[0,0],[0,1],[1,0],[1,1]]
# 2. Compute and_results using perceptron(w1=1, w2=1, bias=-1.5) for each input
# 3. Compute or_results using perceptron(w1=1, w2=1, bias=-0.5) for each input
# 4. Print both result lists next to their inputs

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'gate_inputs' in dir(), "Variable 'gate_inputs' not found."
assert 'and_results' in dir(), "Variable 'and_results' not found."
assert 'or_results' in dir(), "Variable 'or_results' not found."

assert list(and_results) == [0, 0, 0, 1], f"Expected AND results [0,0,0,1], got {list(and_results)}"
assert list(or_results) == [0, 1, 1, 1], f"Expected OR results [0,1,1,1], got {list(or_results)}"
assert len(gate_inputs) == 4, "gate_inputs should contain exactly 4 combinations."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>10. Exercise 6 — Visualizing the Decision Boundary</h2>
# <h3>تمرين 6 — رسم خط الفصل (Decision Boundary)</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> الفصل الخطي (Linear Separation) — العصبون كخط فاصل</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من اشتقاق معادلة خط الفصل من أوزان وانحياز عصبون بوابة AND، ورسمها باستخدام Matplotlib لفهم المعنى الهندسي للعصبون بصرياً.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">تعلمت في الدرس أن معادلة العصبون w<sub>1</sub>x<sub>1</sub> + w<sub>2</sub>x<sub>2</sub> + b = 0 هي نفسها معادلة خط مستقيم. سنستخدم أوزان بوابة AND (<code>w1=1, w2=1, bias=-1.5</code>) لاشتقاق هذا الخط ورسمه، لنرى بصرياً كيف يفصل بين نقطة <code>[1,1]</code> (الفئة الإيجابية) وباقي النقاط.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>حدد <code>w1, w2, b = 1, 1, -1.5</code> (أوزان بوابة AND).</li>
# <li>أنشئ مصفوفة <code>x_vals = np.linspace(-0.5, 1.5, 100)</code>.</li>
# <li>احسب <code>y_vals</code> من معادلة الخط المشتقة من w<sub>1</sub>x + w<sub>2</sub>y + b = 0 (أي <code>y_vals = -(w1*x_vals + b) / w2</code>).</li>
# <li>ارسم الخط باستخدام <code>plt.plot</code>، وأضف تسمية للمحاور وعنواناً للرسم.</li>
# <li>ارسم فوق الخط النقاط الأربع لبوابة AND (<code>[0,0], [0,1], [1,0], [1,1]</code>) باستخدام <code>plt.scatter</code>، بحيث تكون النقطة <code>[1,1]</code> بلون مختلف عن الباقي (تمثل الفئة <code>1</code>).</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>استخدم <code>matplotlib.pyplot</code> و <code>numpy</code> فقط.</li>
# <li>يجب أن تحسب <code>y_vals</code> من نفس معادلة الخط المذكورة في الدرس ولا تستخدم قيماً جاهزة.</li>
# <li>أسماء المتغيرات: <code>w1</code>, <code>w2</code>, <code>b</code>, <code>x_vals</code>, <code>y_vals</code>.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>رسم بياني يظهر خطاً مستقيماً يفصل تقريباً بين النقطة <code>[1,1]</code> وباقي النقاط الثلاث، مع محاور وعنوان واضحين.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# انطلق من معادلة الخط: $w_1x + w_2y + b = 0$. حل المعادلة من أجل $y$ لتحصل على $y = -(w_1x + b)/w_2$.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# راجع كود الرسم في الدرس: `y_vals = -(w1 * x_vals + b) / w2` هو بالضبط ما تحتاجه هنا، فقط استبدل `w1, w2, b` بقيم بوابة AND.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# لرسم النقاط بألوان مختلفة، افصل بيانات AND إلى نقاط بمخرج `0` ونقاط بمخرج `1`، ثم استدعِ `plt.scatter` مرتين بألوان مختلفة قبل `plt.show()`.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Set w1, w2, b for the AND gate (1, 1, -1.5)
# 2. Create x_vals with np.linspace
# 3. Derive y_vals from the line equation w1*x + w2*y + b = 0
# 4. Plot the decision line with labels/title
# 5. Scatter the 4 AND gate points, highlighting [1,1] differently

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'w1' in dir() and 'w2' in dir() and 'b' in dir(), "w1, w2, b must be defined."
assert (w1, w2, b) == (1, 1, -1.5), f"Expected AND gate weights (1,1,-1.5), got ({w1},{w2},{b})"
assert 'x_vals' in dir(), "Variable 'x_vals' not found."
assert 'y_vals' in dir(), "Variable 'y_vals' not found."
assert len(x_vals) == len(y_vals), "x_vals and y_vals must have the same length."

expected_y = -(w1 * x_vals + b) / w2
assert np.allclose(y_vals, expected_y), "y_vals does not match the derived line equation."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>11. Exercise 7 — Proving a Single Perceptron Fails on XOR</h2>
# <h3>تمرين 7 — إثبات عجز العصبون الواحد عن حل XOR</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> عدم القابلية للفصل الخطي (Non-linear Separability) — بوابة XOR</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تُثبت عملياً — وليس نظرياً فقط — أنه لا توجد أي مجموعة أوزان وانحياز لعصبون واحد تحل بوابة XOR بدقة 100%، عبر تجربة عدد كبير من الأوزان العشوائية وقياس أفضل دقة ممكنة.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">تعلمت أن بوابة XOR غير قابلة للفصل الخطي. بدلاً من تصديق ذلك نظرياً، سنجرّب آلاف التوليفات العشوائية من الأوزان والانحياز على دالة <code>perceptron</code> نفسها التي بنيتها، ونرى ما هي أعلى دقة يمكن أن يصل إليها عصبون واحد أبداً على بيانات XOR.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف <code>xor_inputs = [[0,0],[0,1],[1,0],[1,1]]</code> و <code>xor_targets = [0, 1, 1, 0]</code>.</li>
# <li>اكتب حلقة تكرارية تجرّب <code>2000</code> توليفة عشوائية من <code>w1, w2, bias</code> (استخدم <code>np.random.uniform(-2, 2)</code> لكل منها).</li>
# <li>لكل توليفة، احسب دقة <code>perceptron</code> على المدخلات الأربعة (نسبة المطابقة مع <code>xor_targets</code>).</li>
# <li>خزّن أعلى دقة تم الوصول إليها عبر كل المحاولات في متغير <code>best_xor_accuracy</code>.</li>
# <li>اطبع أعلى دقة تم الوصول إليها، ووضّح إن كانت الشبكة قد نجحت في حل XOR بالكامل (دقة 1.0) أم لا.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>استخدم دالة <code>perceptron</code> التي بنيتها في التمرين 4.</li>
# <li>استخدم <code>np.random.uniform(-2, 2)</code> لتوليد كل وزن وانحياز عشوائي.</li>
# <li><code>best_xor_accuracy</code> يجب أن تكون رقماً عشرياً بين <code>0</code> و <code>1</code>.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>best_xor_accuracy</code> يجب أن تكون دائماً أقل من <code>1.0</code> (غالباً <code>0.75</code> كحد أقصى)، مهما بلغ عدد المحاولات العشوائية — لأن عصبوناً واحداً لا يستطيع فصل بيانات XOR خطياً مهما كانت أوزانه.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# الدقة (Accuracy) تُحسب كنسبة عدد التوقعات الصحيحة إلى إجمالي عدد النقاط الأربع.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# داخل كل تكرار، ولّد `w1, w2, bias` عشوائياً، ثم احسب `predictions = [perceptron(x[0], x[1], w1, w2, bias) for x in xor_inputs]`، ثم قارنها بـ `xor_targets`.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# لحساب الدقة: `accuracy = sum(p == t for p, t in zip(predictions, xor_targets)) / len(xor_targets)`. حدّث `best_xor_accuracy` فقط إذا كانت الدقة الجديدة أعلى من القيمة الحالية.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define xor_inputs and xor_targets
# 2. Loop over 2000 random (w1, w2, bias) combinations using np.random.uniform(-2, 2)
# 3. For each combination, compute perceptron predictions and their accuracy
# 4. Track the best accuracy found in best_xor_accuracy
# 5. Print best_xor_accuracy and state whether XOR was fully solved

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'xor_inputs' in dir(), "Variable 'xor_inputs' not found."
assert 'xor_targets' in dir(), "Variable 'xor_targets' not found."
assert 'best_xor_accuracy' in dir(), "Variable 'best_xor_accuracy' not found."

assert xor_targets == [0, 1, 1, 0], "xor_targets should be the XOR truth table [0,1,1,0]."
assert 0.0 <= best_xor_accuracy <= 1.0, "best_xor_accuracy must be a fraction between 0 and 1."
assert best_xor_accuracy < 1.0, (
    "A single perceptron should NEVER reach 100% accuracy on XOR — "
    "if it did, double-check your accuracy calculation."
)
assert best_xor_accuracy >= 0.5, "Even a poor search should find at least 50% accuracy on XOR by chance."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>12. Exercise 8 — A Two-Layer Network That Solves XOR</h2>
# <h3>تمرين 8 — شبكة من طبقتين تحل مشكلة XOR</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> الطبقة المخفية (Hidden Layer) — حل XOR بشبكة متعددة الطبقات</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من بناء شبكة من طبقتين (Hidden Layer + Output Layer) باستخدام عصبونات Perceptron بسيطة، ودمج مخرجات بوابتي OR و NAND في الطبقة المخفية للحصول على XOR في طبقة الخرج.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">رأيت في التمرين السابق أن عصبوناً واحداً يفشل في حل XOR. الحل — كما شرح الدرس — هو "ثني" المساحة بإضافة طبقة مخفية: عصبون أول يتعلم OR، وعصبون ثانٍ يتعلم NAND، ثم عصبون الخرج يدمج مخرجيهما (بمنطق AND) للحصول على XOR الصحيحة.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف دالة <code>xor_network(x1, x2)</code> تستخدم دالة <code>perceptron</code> (من التمرين 4) ثلاث مرات بالتسلسل التالي:
#    <ul style="direction: rtl; text-align: right; margin-top: 5px;">
#    <li><code>h1 = perceptron(x1, x2, w1=1, w2=1, bias=-0.5)</code> (عصبون OR).</li>
#    <li><code>h2 = perceptron(x1, x2, w1=-1, w2=-1, bias=1.5)</code> (عصبون NAND).</li>
#    <li><code>output = perceptron(h1, h2, w1=1, w2=1, bias=-1.5)</code> (عصبون AND يدمج h1 و h2).</li>
#    <li>تُعيد الدالة <code>output</code>.</li>
#    </ul>
# </li>
# <li>اختبر <code>xor_network</code> على المدخلات الأربعة <code>[[0,0],[0,1],[1,0],[1,1]]</code> وخزّن النتائج في قائمة <code>xor_network_results</code>.</li>
# <li>اطبع كل مدخل مع الناتج المقابل له.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>يجب استخدام دالة <code>perceptron</code> الموجودة مسبقاً — لا تكتب دالة تنشيط جديدة من الصفر.</li>
# <li>الدالة <code>xor_network</code> يجب أن تُعيد قيمة واحدة (<code>0</code> أو <code>1</code>) لكل استدعاء.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>xor_network_results</code> يجب أن تساوي <code>[0, 1, 1, 0]</code> — أي مطابقة تامة لجدول حقيقة XOR الحقيقي.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# لاحظ أن مخرج الطبقة المخفية (`h1`, `h2`) يصبح هو المدخل لعصبون طبقة الخرج — هذا بالضبط معنى "التمرير الأمامي عبر طبقات متعددة".
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# جدول حقيقة NAND هو عكس AND تماماً: `[1,1,1,0]`. لهذا السبب الأوزان في `h2` سالبة (`w1=-1, w2=-1`) والانحياز موجب (`bias=1.5`) — عكس إشارات AND تماماً.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# بنية الدالة الكاملة: احسب `h1` و `h2` أولاً من `(x1, x2)`، ثم مرّر `(h1, h2)` كمدخلين جديدين إلى `perceptron` الثالث للحصول على `output` النهائي.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define xor_network(x1, x2) using three perceptron() calls (OR, NAND, then AND on top)
# 2. Test it on all 4 XOR inputs and store results in xor_network_results
# 3. Print each input with its output

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'xor_network' in dir(), "Function 'xor_network' not found."
assert callable(xor_network), "'xor_network' should be a function."
assert 'xor_network_results' in dir(), "Variable 'xor_network_results' not found."

assert list(xor_network_results) == [0, 1, 1, 0], (
    f"Expected the two-layer network to reproduce XOR [0,1,1,0], got {list(xor_network_results)}"
)
assert xor_network(0, 0) == 0 and xor_network(1, 1) == 0, "xor_network should output 0 for [0,0] and [1,1]."
assert xor_network(0, 1) == 1 and xor_network(1, 0) == 1, "xor_network should output 1 for [0,1] and [1,0]."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>13. Exercise 9 — Perceptron Learning Rule</h2>
# <h3>تمرين 9 — قاعدة تعلم البيرسيبترون</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> قاعدة تعلم البيرسيبترون (Perceptron Learning Rule) — تحديث الأوزان تلقائياً</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من تطبيق قاعدة تعلم البيرسيبترون لتحديث الأوزان والانحياز تلقائياً بناءً على الخطأ، بدلاً من ضبطها يدوياً كما فعلت في التمارين السابقة.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">في كل التمارين السابقة، اخترت الأوزان يدوياً. الآن سندع العصبون "يتعلّم" الأوزان الصحيحة لبوابة AND بنفسه، بدءاً من أوزان عشوائية، باستخدام معادلة تحديث الأوزان: <code>New Weight = Old Weight + (learning_rate &times; Error &times; Input)</code>.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>عرّف دالة <code>train_step(x1, x2, target, w1, w2, bias, lr)</code> تقوم بـ:
#    <ul style="direction: rtl; text-align: right; margin-top: 5px;">
#    <li>حساب التوقع الحالي عبر <code>perceptron(x1, x2, w1, w2, bias)</code>.</li>
#    <li>حساب الخطأ: <code>error = target - prediction</code>.</li>
#    <li>تحديث الأوزان: <code>w1 += lr * error * x1</code>, <code>w2 += lr * error * x2</code>, <code>bias += lr * error</code>.</li>
#    <li>إعادة <code>w1, w2, bias</code> المحدّثة.</li>
#    </ul>
# </li>
# <li>هيّئ <code>w1, w2, bias</code> بقيم عشوائية صغيرة عبر <code>np.random.uniform(-1, 1, 3)</code>.</li>
# <li>درّب العصبون على بيانات بوابة AND (<code>inputs = [[0,0],[0,1],[1,0],[1,1]]</code>, <code>targets = [0,0,0,1]</code>) لمدة <code>100</code> دورة تدريبية (Epochs) بمعدل تعلم <code>lr = 0.1</code>.</li>
# <li>بعد التدريب، اختبر العصبون على المدخلات الأربعة وخزّن النتائج في <code>trained_and_results</code>.</li>
# <li>اطبع الأوزان النهائية والنتائج بعد التدريب.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>يجب استخدام دالة <code>perceptron</code> من التمرين 4 داخل <code>train_step</code>.</li>
# <li>يجب أن تتبع معادلة التحديث بالضبط كما وردت في الدرس.</li>
# <li><code>trained_and_results</code> يجب أن تكون قائمة من 4 عناصر.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>بعد 100 دورة تدريبية، يجب أن يتعلم العصبون منطق بوابة AND بدقة كاملة، أي <code>trained_and_results == [0, 0, 0, 1]</code>.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع معادلات الدرس: $\text{Error} = y - \hat{y}$، ثم $\text{New Weight} = \text{Old Weight} + (\eta \times \text{Error} \times \text{Input})$.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# كرر التدريب على كل نقطة من نقاط AND الأربع في كل Epoch، وحدّث الأوزان بعد كل نقطة (وليس فقط في نهاية الـ Epoch).
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# بنية حلقة التدريب: `for epoch in range(100): for i, x in enumerate(inputs): w1, w2, bias = train_step(x[0], x[1], targets[i], w1, w2, bias, lr)`.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Define train_step(x1, x2, target, w1, w2, bias, lr) using the perceptron learning rule
# 2. Initialize w1, w2, bias randomly
# 3. Train on the AND gate data for 100 epochs with lr=0.1
# 4. Test the trained perceptron and store results in trained_and_results
# 5. Print the final weights and results

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'train_step' in dir(), "Function 'train_step' not found."
assert callable(train_step), "'train_step' should be a function."
assert 'trained_and_results' in dir(), "Variable 'trained_and_results' not found."
assert 'w1' in dir() and 'w2' in dir() and 'bias' in dir(), "Final w1, w2, bias must exist after training."

assert list(trained_and_results) == [0, 0, 0, 1], (
    f"Expected the trained perceptron to learn AND [0,0,0,1], got {list(trained_and_results)}"
)

# Verify train_step actually moves weights when there is an error
# (with w1=w2=bias=0, perceptron(1,1,0,0,0) predicts 1, so target=0 forces a real update)
w1_test, w2_test, bias_test = 0.0, 0.0, 0.0
w1_new, w2_new, bias_new = train_step(1, 1, 0, w1_test, w2_test, bias_test, 0.1)
assert (w1_new, w2_new, bias_new) != (0.0, 0.0, 0.0), "train_step should update weights when there is an error."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>14. Exercise 10 — Multi-Layer Forward Pass with the Modern Neuron</h2>
# <h3>تمرين 10 — التمرير الأمامي متعدد الطبقات مع العصبون الحديث</h3>
#
# <p style="direction: rtl; text-align: right;"><strong>Topic:</strong> الطبقات (Layers)، ضرب المصفوفات (Matrix Multiplication)، التمرير الأمامي (Forward Pass)، العصبون الحديث (Modern Neuron) مع ReLU</p>
#
# <h3 style="direction: rtl;">Learning Objective</h3>
# <p style="direction: rtl; text-align: right;">أن تتمكن من بناء طبقة كاملة من عدة عصبونات باستخدام ضرب المصفوفات دفعة واحدة، ثم تمرير مخرجاتها كمدخلات لطبقة تالية مع تطبيق دالة تنشيط ReLU — وهذا هو جوهر العصبون الحديث والشبكات متعددة الطبقات.</p>
#
# <h3 style="direction: rtl;">Scenario</h3>
# <p style="direction: rtl; text-align: right;">في الواقع، لا يوجد عصبون واحد بمفرده، بل طبقات كاملة من العصبونات تعمل معاً وتنتقل مخرجاتها من طبقة لأخرى. سنبني هنا طبقة مخفية من 3 عصبونات حديثة (تستخدم ReLU بدل Step)، ثم نمرر مخرجاتها إلى عصبون خرج واحد.</p>
#
# <h3 style="direction: rtl;">Task</h3>
# <p style="direction: rtl; text-align: right;">اكتب كوداً يقوم بالتالي:</p>
# <ol style="direction: rtl; text-align: right;">
# <li>أنشئ <code>inputs = np.array([0.5, 0.8])</code>.</li>
# <li>أنشئ مصفوفة أوزان الطبقة المخفية <code>weights_layer</code> بأبعاد <code>(2, 3)</code> بالقيم التالية:<br>
# <pre style="direction: ltr; text-align: left; background-color: #f5f5f5; padding: 8px; border-radius: 5px; margin: 5px 0;">
# [[0.2, 0.5, -0.1],
#  [0.7, -0.3, 0.4]]
# </pre>
# وأنشئ <code>biases_layer = np.array([0.1, 0.2, -0.1])</code>.</li>
# <li>احسب الجمع المرجح لكل العصبونات الثلاثة دفعة واحدة عبر ضرب مصفوفات: <code>layer_z = np.dot(inputs, weights_layer) + biases_layer</code>.</li>
# <li>طبّق ReLU (استخدم دالة <code>relu</code> من التمرين 3) على <code>layer_z</code> وخزّن الناتج في <code>layer_outputs</code>.</li>
# <li>أنشئ عصبون خرج واحد بأوزان <code>weights_output = np.array([0.4, 0.9, -0.5])</code> وانحياز <code>bias_output = 0.5</code>، واحسب <code>final_output = np.dot(layer_outputs, weights_output) + bias_output</code>.</li>
# <li>اطبع <code>layer_outputs</code> و <code>final_output</code>.</li>
# </ol>
#
# <h3 style="direction: rtl;">Requirements</h3>
# <ul style="direction: rtl; text-align: right;">
# <li>يجب استخدام <code>np.dot</code> لضرب المصفوفات في كلتا الخطوتين (الطبقة المخفية وطبقة الخرج).</li>
# <li>يجب استخدام دالة <code>relu</code> (وليس Step Function) على مخرجات الطبقة المخفية.</li>
# <li>أسماء المتغيرات: <code>inputs</code>, <code>weights_layer</code>, <code>biases_layer</code>, <code>layer_z</code>, <code>layer_outputs</code>, <code>weights_output</code>, <code>bias_output</code>, <code>final_output</code>.</li>
# </ul>
#
# <h3 style="direction: rtl;">Expected Result</h3>
# <ul style="direction: rtl; text-align: right;">
# <li><code>layer_outputs</code> مصفوفة من 3 قيم غير سالبة (بسبب ReLU)، و <code>final_output</code> قيمة عددية واحدة تمثل ناتج الشبكة الكامل بعد طبقتين.</li>
# </ul>
#
# </div>

# %% [markdown]
# ### Hints
#
# <details>
# <summary>💡 Hint 1</summary>
#
# راجع كود الدرس: `layer_outputs = np.dot(inputs, weights_layer) + biases` يحسب مخرجات 3 عصبونات دفعة واحدة، بدل استدعاء عصبون واحد ثلاث مرات منفصلة.
#
# </details>
#
# <details>
# <summary>💡 Hint 2</summary>
#
# بعد حساب `layer_z`، طبّق `relu(layer_z)` لتحويلها إلى `layer_outputs` — هذه هي إضافة العصبون الحديث فوق الكود الأساسي في الدرس.
#
# </details>
#
# <details>
# <summary>💡 Hint 3</summary>
#
# مخرجات الطبقة المخفية (`layer_outputs`) تصبح هي "المدخلات" للطبقة التالية تماماً كما في الدرس: `final_output = np.dot(layer_outputs, weights_output) + bias_output`.
#
# </details>
#
# ---
#
# ### 🧑‍💻 Your Solution

# %%
# TODO:
# 1. Create inputs = [0.5, 0.8]
# 2. Create weights_layer (2x3) and biases_layer (3,) for the hidden layer
# 3. Compute layer_z via matrix multiplication (np.dot) + biases_layer
# 4. Apply relu(layer_z) -> layer_outputs
# 5. Create weights_output, bias_output for the output neuron and compute final_output
# 6. Print layer_outputs and final_output

# Write your solution here

# %% [markdown]
# ### ✅ Self-Check

# %%
assert 'inputs' in dir(), "Variable 'inputs' not found."
assert 'weights_layer' in dir(), "Variable 'weights_layer' not found."
assert 'biases_layer' in dir(), "Variable 'biases_layer' not found."
assert 'layer_z' in dir(), "Variable 'layer_z' not found."
assert 'layer_outputs' in dir(), "Variable 'layer_outputs' not found."
assert 'final_output' in dir(), "Variable 'final_output' not found."

assert weights_layer.shape == (2, 3), f"Expected weights_layer shape (2,3), got {weights_layer.shape}"
assert biases_layer.shape == (3,), f"Expected biases_layer shape (3,), got {biases_layer.shape}"
assert layer_outputs.shape == (3,), f"Expected layer_outputs shape (3,), got {layer_outputs.shape}"

assert np.all(layer_outputs >= 0), "layer_outputs must be non-negative — did you apply ReLU?"

expected_z = np.dot(np.array([0.5, 0.8]), weights_layer) + biases_layer
expected_outputs = np.maximum(0, expected_z)
assert np.allclose(layer_outputs, expected_outputs), "layer_outputs does not match ReLU(weighted sum)."

assert isinstance(final_output, (float, np.floating)), "final_output should be a single numeric value."

print("✅ Basic checks passed.")

# %% [markdown]
# <div dir="rtl">
# <h2>15. Practical Skills Checklist</h2>
#
# <p style="direction: rtl; text-align: right;">راجع القائمة التالية وتأكد أنك قادر فعلاً على كل بند قبل الانتقال للمستوى التالي:</p>
#
# <ul style="direction: rtl; text-align: right;">
# <li>☐ أستطيع حساب الجمع المرجح (Weighted Sum) يدوياً باستخدام <code>np.dot</code>.</li>
# <li>☐ أفهم كيف تغيّر الأوزان استجابة العصبون لنفس المدخلات.</li>
# <li>☐ أستطيع تطبيق دالة العتبة (Step Function) ودالة ReLU وأفهم الفرق بينهما.</li>
# <li>☐ أستطيع بناء دالة Perceptron كاملة تجمع بين الجمع المرجح والتنشيط.</li>
# <li>☐ أستطيع ضبط أوزان وانحياز عصبون واحد ليحاكي بوابتي AND و OR.</li>
# <li>☐ أستطيع اشتقاق ورسم خط الفصل (Decision Boundary) لعصبون واحد.</li>
# <li>☐ أستطيع إثبات عملياً أن عصبوناً واحداً لا يستطيع حل مشكلة XOR.</li>
# <li>☐ أستطيع بناء شبكة من طبقتين (Hidden + Output) تحل XOR بدمج OR و NAND.</li>
# <li>☐ أستطيع تطبيق قاعدة تعلم البيرسيبترون لتحديث الأوزان تلقائياً من الأخطاء.</li>
# <li>☐ أستطيع بناء طبقة من عدة عصبونات بضرب المصفوفات وتنفيذ Forward Pass متعدد الطبقات مع ReLU.</li>
# </ul>
#
# </div>
#
# ---

# %% [markdown]
# <div dir="rtl">
# <h2>16. Completion Summary</h2>
#
# <h3 style="direction: rtl;">ما الذي تدرّبت عليه (What You Practiced)</h3>
#
# <ul style="direction: rtl; text-align: right;">
# <li>العصبون (Neuron)، المدخلات (Inputs)، الأوزان (Weights)، الانحياز (Bias).</li>
# <li>الجمع المرجح (Weighted Sum) باستخدام NumPy.</li>
# <li>دوال التنشيط (Activation Functions): Step Function و ReLU.</li>
# <li>الـ Perceptron كمصنّف ثنائي خطي (Linear Binary Classifier).</li>
# <li>بوابتا AND و OR كأمثلة على الفصل الخطي (Linear Separability).</li>
# <li>خط الفصل (Decision Boundary) والمعنى الهندسي للعصبون.</li>
# <li>بوابة XOR كمثال على عدم القابلية للفصل الخطي (Non-linear Separability).</li>
# <li>الشبكة متعددة الطبقات (Multi-layer Network) وحل XOR بإضافة طبقة مخفية.</li>
# <li>قاعدة تعلم البيرسيبترون (Perceptron Learning Rule) وتحديث الأوزان.</li>
# <li>الطبقات (Layers)، ضرب المصفوفات (Matrix Multiplication)، والتمرير الأمامي (Forward Pass) في العصبون الحديث.</li>
# </ul>
#
# <p style="direction: rtl; text-align: right;"><strong>🎉 مبروك على إتمام هذا المختبر العملي!</strong></p>
#
# <p style="direction: rtl; text-align: right;">لقد انتقلت من حساب عصبون واحد يدوياً، إلى بناء شبكة صغيرة تتعلم بنفسها وتحل مشكلة كانت مستحيلة على عصبون واحد. هذه هي بالضبط الأساسيات التي تُبنى عليها كل شبكة تعلم عميق حديثة.</p>
#
# </div>
