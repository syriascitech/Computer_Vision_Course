# %% [markdown]
# <div dir="rtl">
#
# # 🗓️ جدول المسابقات الأسبوعية - دورة رؤية الحاسوب
#
#
# ---
# **المُعد/المؤلف:** [Latifa Abdalrazak](https://www.linkedin.com/in/latifa-abd-alrazak-6075a4391/?skipRedirect=true)
#
# ---
#
# ## 📌 مقدمة
# هذا الملف يضم جميع روابط مسابقات الكاهوت الأسبوعية المصممة لمتابعة دورة رؤية الحاسوب.
#
# ### أهداف المسابقات:
# - تعزيز الفهم النظري للمفاهيم المطروحة كل أسبوع
# - تقييم التقدم الشخصي
# - خلق جو تنافسي محفز
#
# ---
#
# ## 📅 الجدول الزمني
#
# | الأسبوع | التاريخ | الموضوع | رابط المسابقة |
# |---------|---------|---------|----------------|
# | الأول | 20/6/2026 | Python Basics Part 1 | [اضغط هنا](https://play.kahoot.it/v2/?quizId=a98e2f49-89fe-49f1-ad79-4ad49add2a6d&hostId=af1d8e3f-23d3-433d-969d-01861c363adc) |
# | الأول | 20/6/2026 | Python Basics Part 2 | [اضغط هنا](https://play.kahoot.it/v2?quizId=7d7dc896-1128-4a20-8730-7b5ebff1d1a4&activeWorkspace=PERSONAL&hostId=af1d8e3f-23d3-433d-969d-01861c363adc&autoAuth=true) |
# | الثاني | 27/6/2026 | OpenCV | [اضغط هنا](https://play.kahoot.it/v2?quizId=dea966d1-c82d-49c9-b32a-37cf23a71726&activeWorkspace=PERSONAL&hostId=af1d8e3f-23d3-433d-969d-01861c363adc&autoAuth=true) |
# | الثاني | 27/6/2026 | Histogram | [اضغط هنا](https://play.kahoot.it/v2?quizId=31a38905-b583-4d23-8659-177685287530&activeWorkspace=PERSONAL&hostId=af1d8e3f-23d3-433d-969d-01861c363adc&autoAuth=true) |
# | الثالث | 4/7/2026 | Filters | [اضغط هنا](https://play.kahoot.it/v2?quizId=c35ef9b0-cbb8-40c9-9222-db4c73e1d730&activeWorkspace=PERSONAL&hostId=af1d8e3f-23d3-433d-969d-01861c363adc&autoAuth=true) |
# | الرابع | 11/7/2026 | Neural Network | [اضغط هنا](https://play.kahoot.it/v2/?quizId=69a2370a-2c40-4744-9f29-05873f7d4c51&hostId=af1d8e3f-23d3-433d-969d-01861c363adc) |
# | الخامس | 18/7/2026 | CNN | [اضغط هنا](https://play.kahoot.it/v2?quizId=44fe59c7-088f-4746-9bbd-3025da8f3ccd&activeWorkspace=PERSONAL&hostId=af1d8e3f-23d3-433d-969d-01861c363adc&autoAuth=true) |
#
# ---
#
# ## 📋 تعليمات المشاركة
# 1. اضغط على رابط المسابقة المطلوبة
# 2. أدخل اسمك الحقيقي أو اسم مستخدم معروف
# 3. أجب على الأسئلة في الوقت المحدد
# 4. راجع الإجابات الخاطئة بعد الانتهاء
#
# ---
#
# ## 💡 نصائح للتحضير
# - راجع محاضرات الأسبوع قبل المشاركة
# - طبّق الأمثلة العملية بنفسك
# - ناقش النقاط الصعبة مع زملائك
#
# ---
# *آخر تحديث: 28/7/2026*
#
# </div>
